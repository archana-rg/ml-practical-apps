# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import plotly.express as px
import numpy as np

# %% [markdown]
# ## Problems
#
# Use the prompts below to get started with your data analysis.

# %% [markdown]
# ## 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %% [markdown]
# ## 2. Investigate the dataset for missing or problematic data.

# %% [markdown]
# ## <font color='green'> Data Understanding</font>

# %%
#Verify Null/NaN values
data.isna().sum()
#Decision : Need to see if there is a correlation between other column values and the missing value column.
#'car' column has too many missing values and should be dropped if no impact
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %%
#Verify the duplicate rows
data[data.duplicated(keep=False)]
#Decision : Drop all duplicates
# Out:
#      destination passanger weather  temperature  time                 coupon  \
# 4191        Work     Alone   Sunny           80   7AM  Carry out & Take away
# 4192        Work     Alone   Sunny           80   7AM  Carry out & Take away
# 4235        Work     Alone   Sunny           80   7AM  Carry out & Take away
# 4236        Work     Alone   Sunny           80   7AM  Carry out & Take away
# 4279        Work     Alone   Sunny           80   7AM  Carry out & Take away
# ...          ...       ...     ...          ...   ...                    ...
# 8511        Home     Alone   Sunny           80   6PM                    Bar
# 8512        Home   Partner   Sunny           30  10PM  Carry out & Take away
# 8513        Work     Alone   Rainy           55   7AM        Restaurant(<20)
# 8515        Work     Alone   Snowy           30   7AM      Restaurant(20-50)
# 8516        Work     Alone   Sunny           80   7AM        Restaurant(<20)
#
# ...

# %%
#Check for any structural issues with data
for col in data.columns:
    print("------------------------\n")
    print(data[col].value_counts())
# Out:
# ------------------------
#
# destination
# No Urgent Place    6283
# Home               3237
# Work               3164
# Name: count, dtype: int64
# ------------------------
#
# passanger
# Alone        7305
# Friend(s)    3298
# Partner      1075
# Kid(s)       1006
# Name: count, dtype: int64
# ------------------------
#
# weather
# Sunny    10069
# Snowy     1405
# Rainy     1210
# Name: count, dtype: int64
# ------------------------
#
# temperature
# 80    6528
# 55    3840
# 30    2316
# Name: count, dtype: int64
# ------------------------
#
# time
# 6PM     3230
# 7AM     3164
# 10AM    2275
# 2PM     2009
# 10PM    2006
# Name: count, dtype: int64
# ------------------------
#
# coupon
# Coffee House             3996
# Restaurant(<20)          2786
# Carry out & Take away    2393
# Bar                      2017
# Restaurant(20-50)        1492
# Name: count, dtype: int64
# ------------------------
#
# expiration
# 1d    7091
# 2h    5593
# Name: count, dtype: int64
# ...

# %% [markdown]
# ### <font color='blue'>Decisions on column data:</font>
# 1. destination - change value No Urgent Place to NonUrgent to be concise
# 2. passanger - rename column name to 'passenger' to fix typo and remove () in the values to keep it simple
# 3. education - simplify value by changing 'Graduate degree (Masters or Doctorate)' to 'Graduate degree' and 'Some college - no degree' to 'Some college'
# 4. occupation - remove spaces between & and professions
# 5. income - use average value of the given range
# 6. Convert Bar, CarryAway, RestaurantX, CoffeeHouse columns to numeric
# 7. Convert age column to numeric

# %% [markdown]
# ## 3. Decide what to do about your missing data -- drop, replace, other...

# %% [markdown]
# ## <font color='green'> Data Cleaning</font>

# %%
#First drop all duplicates
print(data.shape)
data = data.drop_duplicates()
print(data.shape)
# Out:
# (12684, 26)
# (12610, 26)

# %%
#Handle missing values
data.isna().sum()
#Does the type of car affect coupon acceptance
data.groupby('car')[['Y']].mean()
# Out:
#                                                  Y
# car
# Car that is too old to install Onstar :D  0.809524
# Mazda5                                    0.727273
# Scooter and motorcycle                    0.500000
# crossover                                 0.380952
# do not drive                              0.454545

# %%
data_oldcar = data.query('car == "Car that is too old to install Onstar :D"')
for col in data.columns:
    print("------------------------\n")
    print(data_oldcar[col].value_counts())
# Out:
# ------------------------
#
# destination
# No Urgent Place    11
# Home                5
# Work                5
# Name: count, dtype: int64
# ------------------------
#
# passanger
# Alone        13
# Friend(s)     8
# Name: count, dtype: int64
# ------------------------
#
# weather
# Sunny    11
# Snowy     6
# Rainy     4
# Name: count, dtype: int64
# ------------------------
#
# temperature
# 30    8
# 80    7
# 55    6
# Name: count, dtype: int64
# ------------------------
#
# time
# 6PM     6
# 10PM    5
# 7AM     5
# 10AM    4
# 2PM     1
# Name: count, dtype: int64
# ------------------------
#
# coupon
# Coffee House             6
# Restaurant(<20)          5
# Restaurant(20-50)        4
# Carry out & Take away    4
# Bar                      2
# Name: count, dtype: int64
# ------------------------
#
# expiration
# 1d    12
# 2h     9
# Name: count, dtype: int64
# ------------------------
#
# gender
# Male    21
# Name: count, dtype: int64
# ------------------------
#
# age
# ...

# %%
data.groupby('education')[['car', 'occupation', 'maritalStatus', 'age', 'gender']].value_counts()
# Out:
# education                               car                                       occupation                       maritalStatus    age  gender
# Associates degree                       Car that is too old to install Onstar :D  Computer & Mathematical          Single           21   Male      21
# Bachelors degree                        Mazda5                                    Computer & Mathematical          Married partner  26   Male      22
#                                         do not drive                              Office & Administrative Support  Single           26   Female    22
#                                         crossover                                 Legal                            Married partner  41   Female    21
# Graduate degree (Masters or Doctorate)  Scooter and motorcycle                    Sales & Related                  Single           26   Male      22
# Name: count, dtype: int64

# %%
data['education'].value_counts()
# Out:
# education
# Some college - no degree                  4325
# Bachelors degree                          4323
# Graduate degree (Masters or Doctorate)    1827
# Associates degree                         1148
# High School Graduate                       899
# Some High School                            88
# Name: count, dtype: int64

# %% [markdown]
# #### <font color='blue'>Good to drop the 'car' column as it is not clear what to fill it with and even if we do based on education, it will be redundant</font>

# %%
data = data.drop('car', axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12610 entries, 0 to 12683
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12610 non-null  object
#  1   passanger             12610 non-null  object
#  2   weather               12610 non-null  object
#  3   temperature           12610 non-null  int64
#  4   time                  12610 non-null  object
#  5   coupon                12610 non-null  object
#  6   expiration            12610 non-null  object
#  7   gender                12610 non-null  object
#  8   age                   12610 non-null  object
#  9   maritalStatus         12610 non-null  object
#  10  has_children          12610 non-null  int64
#  11  education             12610 non-null  object
#  12  occupation            12610 non-null  object
#  13  income                12610 non-null  object
#  14  Bar                   12503 non-null  object
# ...

# %% [markdown]
# #### <font color='blue'> Find high and low probability labels for coupon being 'X and Y=1 or Y=0, also find median label for the given coupon 'X'. Use these values to fill missing values</font>

# %%
#Coffee House missing value fill
print(data.isna().sum())
data_coffeehouse = data.groupby(['CoffeeHouse', 'coupon'])[['Y']].mean().reset_index()
coffee_label_high = data_coffeehouse.query('coupon == "Coffee House"').sort_values(by='Y', ascending=False).iloc[0,0]
coffee_label_low = data_coffeehouse.query('coupon == "Coffee House"').sort_values(by='Y', ascending=True).iloc[0,0]
coffee_label_median = data_coffeehouse.query('coupon == "Coffee House"')[['Y']].median().reset_index().iloc[0,1]#Get the median value of Y
coffee_label_median = data_coffeehouse.query('coupon == "Coffee House" and Y == @coffee_label_median').iloc[0,0]#Get the label corresponding to median value of Y
print(coffee_label_median,coffee_label_high, coffee_label_low)
# Out:
# destination               0
# passanger                 0
# weather                   0
# temperature               0
# time                      0
# coupon                    0
# expiration                0
# gender                    0
# age                       0
# maritalStatus             0
# has_children              0
# education                 0
# occupation                0
# income                    0
# Bar                     107
# CoffeeHouse             217
# CarryAway               150
# RestaurantLessThan20    129
# Restaurant20To50        189
# toCoupon_GEQ5min          0
# toCoupon_GEQ15min         0
# toCoupon_GEQ25min         0
# direction_same            0
# direction_opp             0
# Y                         0
# dtype: int64
# 1~3 4~8 never

# %%
#Fill the missing CoffeeHouse data
data['CoffeeHouse'] = data.apply(lambda x : coffee_label_high if (pd.isna(x['CoffeeHouse'])) & (x['coupon'] == "Coffee House") & (x['Y'] == 1) else x['CoffeeHouse'], axis=1)
data['CoffeeHouse'] = data.apply(lambda x : coffee_label_low  if (pd.isna(x['CoffeeHouse'])) & (x['coupon'] == "Coffee House") & (x['Y'] == 0) else x['CoffeeHouse'], axis=1)
data['CoffeeHouse'] = data.apply(lambda x : coffee_label_median if pd.isna(x['CoffeeHouse']) else x['CoffeeHouse'], axis=1)
print(data.isna().sum())
# Out:
# destination               0
# passanger                 0
# weather                   0
# temperature               0
# time                      0
# coupon                    0
# expiration                0
# gender                    0
# age                       0
# maritalStatus             0
# has_children              0
# education                 0
# occupation                0
# income                    0
# Bar                     107
# CoffeeHouse               0
# CarryAway               150
# RestaurantLessThan20    129
# Restaurant20To50        189
# toCoupon_GEQ5min          0
# toCoupon_GEQ15min         0
# toCoupon_GEQ25min         0
# direction_same            0
# direction_opp             0
# Y                         0
# dtype: int64

# %%
#Fill Bar missing values
data_bar = data.groupby(['Bar', 'coupon'])[['Y']].mean().reset_index()
bar_label_high = data_bar.query('coupon == "Bar"').sort_values(by='Y', ascending=False).iloc[0,0]
bar_label_low = data_bar.query('coupon == "Bar"').sort_values(by='Y', ascending=True).iloc[0,0]
bar_label_median = data_bar.query('coupon == "Bar"')[['Y']].median().reset_index().iloc[0,1]#Get the median value of Y
bar_label_median = data_bar.query('coupon == "Bar" and Y == @bar_label_median').iloc[0,0]#Get the label corresponding to median value of Y
print(bar_label_median,bar_label_high, bar_label_low)
print(data_bar)
# Out:
# 1~3 4~8 never
#       Bar                 coupon         Y
# 0     1~3                    Bar  0.647355
# 1     1~3  Carry out & Take away  0.759657
# 2     1~3           Coffee House  0.498688
# 3     1~3      Restaurant(20-50)  0.473684
# 4     1~3        Restaurant(<20)  0.729391
# 5     4~8                    Bar  0.780000
# 6     4~8  Carry out & Take away  0.735450
# 7     4~8           Coffee House  0.524324
# 8     4~8      Restaurant(20-50)  0.435484
# 9     4~8        Restaurant(<20)  0.743697
# 10    gt8                    Bar  0.734694
# 11    gt8  Carry out & Take away  0.569231
# 12    gt8           Coffee House  0.451327
# 13    gt8      Restaurant(20-50)  0.595238
# 14    gt8        Restaurant(<20)  0.658228
# 15  less1                    Bar  0.444050
# 16  less1  Carry out & Take away  0.712286
# 17  less1           Coffee House  0.504202
# 18  less1      Restaurant(20-50)  0.420398
# 19  less1        Restaurant(<20)  0.683794
# ...

# %%
data['Bar'] = data.apply(lambda x : bar_label_high if (pd.isna(x['Bar'])) & (x['coupon'] == "Bar") & (x['Y'] == 1) else x['Bar'], axis=1)
data['Bar'] = data.apply(lambda x : bar_label_low  if (pd.isna(x['Bar'])) & (x['coupon'] == "Bar") & (x['Y'] == 0) else x['Bar'], axis=1)
data['Bar'] = data.apply(lambda x : bar_label_median if pd.isna(x['Bar'])  else x['Bar'], axis=1)
print(data.isna().sum())
# Out:
# destination               0
# passanger                 0
# weather                   0
# temperature               0
# time                      0
# coupon                    0
# expiration                0
# gender                    0
# age                       0
# maritalStatus             0
# has_children              0
# education                 0
# occupation                0
# income                    0
# Bar                       0
# CoffeeHouse               0
# CarryAway               150
# RestaurantLessThan20    129
# Restaurant20To50        189
# toCoupon_GEQ5min          0
# toCoupon_GEQ15min         0
# toCoupon_GEQ25min         0
# direction_same            0
# direction_opp             0
# Y                         0
# dtype: int64

# %%
#Fill CarryAway missing values
data_carryaway = data.groupby(['CarryAway', 'coupon'])[['Y']].mean().reset_index()
carry_label_high = data_carryaway.query('coupon == "Carry out & Take away"').sort_values(by='Y', ascending=False).iloc[0,0]
carry_label_low = data_carryaway.query('coupon == "Carry out & Take away"').sort_values(by='Y', ascending=True).iloc[0,0]
carry_label_median = data_carryaway.query('coupon == "Carry out & Take away"')[['Y']].median().reset_index().iloc[0,1]#Get the median value of Y
carry_label_median = data_carryaway.query('coupon == "Carry out & Take away" and Y == @carry_label_median').iloc[0,0]#Get the label corresponding to median value of Y
print(carry_label_median,carry_label_high, carry_label_low)
print(data_carryaway)
# Out:
# 1~3 4~8 less1
#    CarryAway                 coupon         Y
# 0        1~3                    Bar  0.413840
# 1        1~3  Carry out & Take away  0.734982
# 2        1~3           Coffee House  0.512735
# 3        1~3      Restaurant(20-50)  0.460695
# 4        1~3        Restaurant(<20)  0.732353
# 5        4~8                    Bar  0.417910
# 6        4~8  Carry out & Take away  0.753731
# 7        4~8           Coffee House  0.510813
# 8        4~8      Restaurant(20-50)  0.429474
# 9        4~8        Restaurant(<20)  0.721639
# 10       gt8                    Bar  0.425781
# 11       gt8  Carry out & Take away  0.733788
# 12       gt8           Coffee House  0.502075
# 13       gt8      Restaurant(20-50)  0.472637
# 14       gt8        Restaurant(<20)  0.702941
# 15     less1                    Bar  0.369128
# 16     less1  Carry out & Take away  0.676301
# 17     less1           Coffee House  0.423345
# 18     less1      Restaurant(20-50)  0.387931
# ...

# %%
data['CarryAway'] = data.apply(lambda x : carry_label_high if (pd.isna(x['CarryAway'])) & (x['coupon'] == "Carry out & Take away") & (x['Y'] == 1) else x['CarryAway'], axis=1)
data['CarryAway'] = data.apply(lambda x : carry_label_low  if (pd.isna(x['CarryAway'])) & (x['coupon'] == "Carry out & Take away") & (x['Y'] == 0) else x['CarryAway'], axis=1)
data['CarryAway'] = data.apply(lambda x : carry_label_median if pd.isna(x['CarryAway'])  else x['CarryAway'], axis=1)
print(data.isna().sum())
# Out:
# destination               0
# passanger                 0
# weather                   0
# temperature               0
# time                      0
# coupon                    0
# expiration                0
# gender                    0
# age                       0
# maritalStatus             0
# has_children              0
# education                 0
# occupation                0
# income                    0
# Bar                       0
# CoffeeHouse               0
# CarryAway                 0
# RestaurantLessThan20    129
# Restaurant20To50        189
# toCoupon_GEQ5min          0
# toCoupon_GEQ15min         0
# toCoupon_GEQ25min         0
# direction_same            0
# direction_opp             0
# Y                         0
# dtype: int64

# %%
#Fill restaurant expensive
data_restexp = data.groupby(['Restaurant20To50', 'coupon'])[['Y']].mean().reset_index()
restexp_label_high = data_restexp.query('coupon == "Restaurant(20-50)"').sort_values(by='Y', ascending=False).iloc[0,0]
restexp_label_low = data_restexp.query('coupon == "Restaurant(20-50)"').sort_values(by='Y', ascending=True).iloc[0,0]
restexp_label_median = data_restexp.query('coupon == "Restaurant(20-50)"')[['Y']].median().reset_index().iloc[0,1]#Get the median value of Y
restexp_label_median = data_restexp.query('coupon == "Restaurant(20-50)" and Y == @restexp_label_median').iloc[0,0]#Get the label corresponding to median value of Y
print(restexp_label_median,restexp_label_high, restexp_label_low)
print(data_restexp)
# Out:
# 1~3 gt8 never
#    Restaurant20To50                 coupon         Y
# 0               1~3                    Bar  0.431002
# 1               1~3  Carry out & Take away  0.738617
# 2               1~3           Coffee House  0.515551
# 3               1~3      Restaurant(20-50)  0.527559
# 4               1~3        Restaurant(<20)  0.752137
# 5               4~8                    Bar  0.633333
# 6               4~8  Carry out & Take away  0.753333
# 7               4~8           Coffee House  0.572165
# 8               4~8      Restaurant(20-50)  0.626374
# 9               4~8        Restaurant(<20)  0.693642
# 10              gt8                    Bar  0.628571
# 11              gt8  Carry out & Take away  0.680851
# 12              gt8           Coffee House  0.637363
# 13              gt8      Restaurant(20-50)  0.687500
# 14              gt8        Restaurant(<20)  0.694915
# 15            less1                    Bar  0.388151
# ...

# %%
data['Restaurant20To50'] = data.apply(lambda x : carry_label_high if (pd.isna(x['Restaurant20To50'])) & (x['coupon'] == "Restaurant(20-50)") & (x['Y'] == 1) else x['Restaurant20To50'], axis=1)
data['Restaurant20To50'] = data.apply(lambda x : carry_label_low  if (pd.isna(x['Restaurant20To50'])) & (x['coupon'] == "Restaurant(20-50)") & (x['Y'] == 0) else x['Restaurant20To50'], axis=1)
data['Restaurant20To50'] = data.apply(lambda x : carry_label_median if pd.isna(x['Restaurant20To50'])  else x['Restaurant20To50'], axis=1)
print(data.isna().sum())
# Out:
# destination               0
# passanger                 0
# weather                   0
# temperature               0
# time                      0
# coupon                    0
# expiration                0
# gender                    0
# age                       0
# maritalStatus             0
# has_children              0
# education                 0
# occupation                0
# income                    0
# Bar                       0
# CoffeeHouse               0
# CarryAway                 0
# RestaurantLessThan20    129
# Restaurant20To50          0
# toCoupon_GEQ5min          0
# toCoupon_GEQ15min         0
# toCoupon_GEQ25min         0
# direction_same            0
# direction_opp             0
# Y                         0
# dtype: int64

# %%
#Fill restaurant cheap
data_restcheap = data.groupby(['RestaurantLessThan20', 'coupon'])[['Y']].mean().reset_index()
restcheap_label_high = data_restcheap.query('coupon == "Restaurant(<20)"').sort_values(by='Y', ascending=False).iloc[0,0]
restcheap_label_low = data_restcheap.query('coupon == "Restaurant(<20)"').sort_values(by='Y', ascending=True).iloc[0,0]
restcheap_label_median = data_restcheap.query('coupon == "Restaurant(<20)"')[['Y']].median().reset_index().iloc[0,1]#Get the median value of Y
restcheap_label_median = data_restcheap.query('coupon == "Restaurant(<20)" and Y == @restcheap_label_median').iloc[0,0]#Get the label corresponding to median value of Y
print(restcheap_label_median,restcheap_label_high, restcheap_label_low)
print(data_restcheap)
# Out:
# 1~3 gt8 never
#    RestaurantLessThan20                 coupon         Y
# 0                   1~3                    Bar  0.396355
# 1                   1~3  Carry out & Take away  0.724725
# 2                   1~3           Coffee House  0.500893
# 3                   1~3      Restaurant(20-50)  0.416796
# 4                   1~3        Restaurant(<20)  0.702679
# 5                   4~8                    Bar  0.426549
# 6                   4~8  Carry out & Take away  0.746224
# 7                   4~8           Coffee House  0.512367
# 8                   4~8      Restaurant(20-50)  0.471178
# 9                   4~8        Restaurant(<20)  0.719497
# 10                  gt8                    Bar  0.456989
# 11                  gt8  Carry out & Take away  0.756522
# 12                  gt8           Coffee House  0.522042
# 13                  gt8      Restaurant(20-50)  0.517007
# 14                  gt8        Restaurant(<20)  0.760417
# ...

# %%
data['RestaurantLessThan20'] = data.apply(lambda x : carry_label_high if (pd.isna(x['RestaurantLessThan20'])) & (x['coupon'] == "Restaurant(<20)") & (x['Y'] == 1) else x['RestaurantLessThan20'], axis=1)
data['RestaurantLessThan20'] = data.apply(lambda x : carry_label_low  if (pd.isna(x['RestaurantLessThan20'])) & (x['coupon'] == "Restaurant(<20)") & (x['Y'] == 0) else x['RestaurantLessThan20'], axis=1)
data['RestaurantLessThan20'] = data.apply(lambda x : carry_label_median if pd.isna(x['RestaurantLessThan20'])  else x['RestaurantLessThan20'], axis=1)
print(data.isna().sum())
# Out:
# destination             0
# passanger               0
# weather                 0
# temperature             0
# time                    0
# coupon                  0
# expiration              0
# gender                  0
# age                     0
# maritalStatus           0
# has_children            0
# education               0
# occupation              0
# income                  0
# Bar                     0
# CoffeeHouse             0
# CarryAway               0
# RestaurantLessThan20    0
# Restaurant20To50        0
# toCoupon_GEQ5min        0
# toCoupon_GEQ15min       0
# toCoupon_GEQ25min       0
# direction_same          0
# direction_opp           0
# Y                       0
# dtype: int64

# %% [markdown]
# Fixing structural issues based on the following:
# 1. destination - change value No Urgent Place to NonUrgent to be concise
# 2. passanger - rename column name to 'passenger' to fix typo and remove () in the values to keep it simple
# 3. education - simplify value by changing 'Graduate degree (Masters or Doctorate)' to 'Graduate degree' and 'Some college - no degree' to 'Some college'
# 4. occupation - remove spaces between & and professions
# 5. income - use average value of the given range
# 6. Convert Bar, CarryAway, RestaurantX, CoffeeHouse columns to numeric
# 7. Convert age column to numeric

# %%
data['destination'].value_counts()
data['destination'] = data['destination'].str.replace('No Urgent Place', 'NonUrgent')
data['destination'].value_counts()
# Out:
# destination
# NonUrgent    6266
# Home         3230
# Work         3114
# Name: count, dtype: int64

# %%
data = data.rename(columns = {"passanger" : "passenger"})
data['passenger'].value_counts()
data['passenger'] = data['passenger'].str.replace('\(|\)', "", regex=True)

# %%
data['education'].value_counts()
data['education'] = data['education'].str.replace('Graduate degree (Masters or Doctorate)', 'Graduate degree')
data['education'] = data['education'].str.replace('Some college - no degree', 'Some college')
data['education'].value_counts()
# Out:
# education
# Some college            4325
# Bachelors degree        4323
# Graduate degree         1827
# Associates degree       1148
# High School Graduate     899
# Some High School          88
# Name: count, dtype: int64

# %%
data['occupation'] = data['occupation'].str.replace(" ", "")
data['occupation'].value_counts()
# Out:
# occupation
# Unemployed                              1861
# Student                                 1575
# Computer&Mathematical                   1390
# Sales&Related                           1088
# Education&Training&Library               939
# Management                               821
# Office&AdministrativeSupport             638
# ArtsDesignEntertainmentSports&Media      627
# Business&Financial                       543
# Retired                                  493
# FoodPreparation&ServingRelated           298
# HealthcarePractitioners&Technical        244
# HealthcareSupport                        242
# Community&SocialServices                 239
# Legal                                    219
# Transportation&MaterialMoving            218
# Architecture&Engineering                 175
# PersonalCare&Service                     175
# ProtectiveService                        174
# LifePhysicalSocialScience                169
# Construction&Extraction                  154
# ...

# %%
#First make all values $x - $y format
data['income'] = data['income'].str.replace('Less than $12500', '$0 - $12500').str.replace('$100000 or More', '$100000 - $150000')
print(data['income'].value_counts())
#Function to provide low, high range values
def getLowHighValues(row):
    low = row['income'].split(" ")[0].replace("$", "")
    low = int(low)
    high = row['income'].split(" ")[2].replace("$", "")
    high = int(high)
    return np.array([low,high])

#Convert all ranges to a mean value fo range
data['income'] = data.apply(lambda row : int(np.mean(getLowHighValues(row))), axis=1)
print(data['income'].value_counts())
# Out:
# income
# $25000 - $37499      2006
# $12500 - $24999      1825
# $37500 - $49999      1795
# $100000 - $150000    1717
# $50000 - $62499      1655
# $0 - $12500          1034
# $87500 - $99999       879
# $75000 - $87499       856
# $62500 - $74999       843
# Name: count, dtype: int64
# income
# 31249     2006
# 18749     1825
# 43749     1795
# 125000    1717
# 56249     1655
# 6250      1034
# 93749      879
# 81249      856
# 68749      843
# Name: count, dtype: int64

# %%
data['coupon'] = data['coupon'].str.replace('Carry out & Take away', 'Carry Out')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12610 entries, 0 to 12683
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12610 non-null  object
#  1   passenger             12610 non-null  object
#  2   weather               12610 non-null  object
#  3   temperature           12610 non-null  int64
#  4   time                  12610 non-null  object
#  5   coupon                12610 non-null  object
#  6   expiration            12610 non-null  object
#  7   gender                12610 non-null  object
#  8   age                   12610 non-null  object
#  9   maritalStatus         12610 non-null  object
#  10  has_children          12610 non-null  int64
#  11  education             12610 non-null  object
#  12  occupation            12610 non-null  object
#  13  income                12610 non-null  int64
#  14  Bar                   12610 non-null  object
# ...

# %%
data['Bar']= data['Bar'].str.replace('never', '0').str.replace('less1', '1').str.replace('1~3', '3').str.replace('4~8', '8').str.replace('gt8', '10')
data['CoffeeHouse']= data['CoffeeHouse'].str.replace('never', '0').str.replace('less1', '1').str.replace('1~3', '3').str.replace('4~8', '8').str.replace('gt8', '10')
data['CarryAway']= data['CarryAway'].str.replace('never', '0').str.replace('less1', '1').str.replace('1~3', '3').str.replace('4~8', '8').str.replace('gt8', '10')
data['RestaurantLessThan20']= data['RestaurantLessThan20'].str.replace('never', '0').str.replace('less1', '1').str.replace('1~3', '3').str.replace('4~8', '8').str.replace('gt8', '10')
data['Restaurant20To50']= data['Restaurant20To50'].str.replace('never', '0').str.replace('less1', '1').str.replace('1~3', '3').str.replace('4~8', '8').str.replace('gt8', '10')
#data = pd.to_numeric([data['Bar'], data['CoffeeHouse'], data['CarryAway'], data['RestaurantLessThan20'], data['Restaurant20To50']])
cols = ['Bar', 'CoffeeHouse', 'CarryAway', 'RestaurantLessThan20', 'Restaurant20To50']
data[cols] = data[cols].apply(pd.to_numeric)
data.dtypes
# Out:
# destination             object
# passenger               object
# weather                 object
# temperature              int64
# time                    object
# coupon                  object
# expiration              object
# gender                  object
# age                     object
# maritalStatus           object
# has_children             int64
# education               object
# occupation              object
# income                   int64
# Bar                      int64
# CoffeeHouse              int64
# CarryAway                int64
# RestaurantLessThan20     int64
# Restaurant20To50         int64
# toCoupon_GEQ5min         int64
# toCoupon_GEQ15min        int64
# toCoupon_GEQ25min        int64
# direction_same           int64
# direction_opp            int64
# Y                        int64
# dtype: object

# %%
data['age'].value_counts()
data['age'] = data['age'].str.replace('50plus', '55').str.replace('below21', '20')
data['age'] = pd.to_numeric(data['age'])
data.dtypes
# Out:
# destination             object
# passenger               object
# weather                 object
# temperature              int64
# time                    object
# coupon                  object
# expiration              object
# gender                  object
# age                      int64
# maritalStatus           object
# has_children             int64
# education               object
# occupation              object
# income                   int64
# Bar                      int64
# CoffeeHouse              int64
# CarryAway                int64
# RestaurantLessThan20     int64
# Restaurant20To50         int64
# toCoupon_GEQ5min         int64
# toCoupon_GEQ15min        int64
# toCoupon_GEQ25min        int64
# direction_same           int64
# direction_opp            int64
# Y                        int64
# dtype: object

# %% [markdown]
# ## <font color='green'>Overall HeatMap check</font>

# %%
data_numeric_only = data.select_dtypes(include=['int64'])
data_numeric_only = data_numeric_only.drop('toCoupon_GEQ5min', axis=1)
data_num_corr = data_numeric_only.corr()
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(data_num_corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ## <font color='green'> Visualizing Data and basic analysis</font>

# %% [markdown]
# #### <font color = 'blue'>The above heatmap does not make sense. It shows poor correlation between features, especially between features and the target variable 'Y'. This could be due to the data being mixed up with all coupon types. Later we will redo the heatmap on per coupon data</font>

# %% [markdown]
# ## 4. What proportion of the total observations chose to accept the coupon?

# %%
coupon_accept_proportion = data.query('Y == 1').shape[0] / data.shape[0]
coupon_accept_proportion
# Out:
# 0.5675654242664552

# %% [markdown]
# ## 5. Use a bar plot to visualize the `coupon` column.

# %%
sns.barplot(data=data, x='coupon', y='Y')
plt.title('Coupon Acceptance By Coupon Type')
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Restaurant(<20)'),
#   Text(1, 0, 'Coffee House'),
#   Text(2, 0, 'Carry Out'),
#   Text(3, 0, 'Bar'),
#   Text(4, 0, 'Restaurant(20-50)')])

# %%
sns.displot(data=data, x='coupon', hue = 'Y', multiple='stack')
plt.title('Coupon Acceptance By Coupon Type')
plt.xticks(rotation=90)
# Out:
# /home/archana/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Restaurant(<20)'),
#   Text(1, 0, 'Coffee House'),
#   Text(2, 0, 'Carry Out'),
#   Text(3, 0, 'Bar'),
#   Text(4, 0, 'Restaurant(20-50)')])

# %%
data.groupby('coupon')[['Y']].mean()
# Out:
#                           Y
# coupon
# Bar                0.409950
# Carry Out          0.733788
# Coffee House       0.498621
# Restaurant(20-50)  0.441532
# Restaurant(<20)    0.707809

# %% [markdown]
# #### <font color='blue'> From the above, `Carry Out` and `Restaurant(<20)` have higher acceptance rate than others and in the dataset, `Coffee House` coupons were offered more</font>

# %%
sns.displot(data=data, x='temperature', hue = 'Y', multiple='stack')
# Out:
# /home/archana/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data.groupby('temperature')[['Y']].mean()
# Out:
#                     Y
# temperature
# 30           0.531453
# 55           0.536815
# 80           0.598610

# %% [markdown]
# #### <font color='blue'> The temperature histogram shows more drivers were driving at 80 degree temperature but the acceptance rate did not vary with temperature</font>

# %% [markdown]
# ## 7. Use box and histogram plots for `income` and `age`

# %%
fig = px.box(data, x='age')
fig.update_layout(title='Age data distribution')
fig.show()

sns.displot(data=data, x='age', kind='kde')
plt.title('Age kernel density plot')
#Shows that we have more data for younger drivers
fig = px.box(data, x='income')
fig.update_layout(title='Income data distribution')
fig.show()
sns.displot(data=data, x='income', kind='kde')
plt.title('Income kernel density plot')
#Shows a better representation of all ranges
# Out:
# <div>                            <div id="415bddf4-e90b-4931-8bcf-d593b88c9ef3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("415bddf4-e90b-4931-8bcf-d593b88c9ef3")) {                    Plotly.newPlot(                        "415bddf4-e90b-4931-8bcf-d593b88c9ef3",                        [{"alignmentgroup":"True","hovertemplate":"age=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,46,21,21
# ...

# %%
sns.displot(data=data, x='age', hue = 'Y', multiple='stack')
plt.title('Age and Coupon Acceptance')
sns.displot(data=data, x='income', hue = 'Y', multiple='stack')
plt.title('Income and Coupon Acceptance')
# Out:
# /home/archana/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
#
# /home/archana/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
# Text(0.5, 1.0, 'Income and Coupon Acceptance')

# %% [markdown]
# #### <font color='blue'> Income and Age don't show any interesting trend in acceptance rate of coupon</font>

# %% [markdown]
# ## 8. Use histogram for `passenger` column

# %%
sns.displot(data=data, x='passenger', hue = 'Y', multiple='stack')
plt.xticks(rotation=90)
# Out:
# /home/archana/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Alone'),
#   Text(1, 0, 'Friends'),
#   Text(2, 0, 'Kids'),
#   Text(3, 0, 'Partner')])

# %%
data.groupby('passenger')[['Y']].mean()
# Out:
#                   Y
# passenger
# Alone      0.524421
# Friends    0.673147
# Kids       0.504496
# Partner    0.594013

# %% [markdown]
# #### <font color='blue'> Drivers with Friends or Partner seem to show slightly higher acceptance rate</font>

# %% [markdown]
# ## 9. Analyse what are the other interesting features affecting acceptance rate

# %%
for col in data.columns:
    print(data.groupby(col)[['Y']].mean())
# Out:
#                     Y
# destination
# Home         0.506192
# NonUrgent    0.633418
# Work         0.498715
#                   Y
# passenger
# Alone      0.524421
# Friends    0.673147
# Kids       0.504496
# Partner    0.594013
#                 Y
# weather
# Rainy    0.463394
# Snowy    0.471725
# Sunny    0.593447
#                     Y
# temperature
# 30           0.531453
# 55           0.536815
# 80           0.598610
#              Y
# time
# 10AM  0.607662
# 10PM  0.508254
# 2PM   0.661515
# 6PM   0.584161
# 7AM   0.498715
#                           Y
# coupon
# Bar                0.409950
# Carry Out          0.733788
# Coffee House       0.498621
# Restaurant(20-50)  0.441532
# Restaurant(<20)    0.707809
#                    Y
# expiration
# 1d          0.624378
# 2h          0.495967
#                Y
# gender
# Female  0.546452
# Male    0.589806
#             Y
# age
# 20   0.632353
# 21   0.597653
# 26   0.595369
# 31   0.545815
# 36   0.535308
# 41   0.572084
# ...

# %%
sns.displot(data=data, x='education', hue='Y', multiple='stack')
plt.xticks(rotation=90)
plt.title('Coupon Acceptance by education')
# Out:
# /home/archana/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
# Text(0.5, 1.0, 'Coupon Acceptance by education')

# %% [markdown]
# #### <font color='blue'> `education` = Some High School showed high acceptance rate in the groupby mean above but looking at the plot, the dataset does not seem to have enough entries for this education category. So not a good indicator</font>

# %%
sns.displot(data=data, x='expiration', hue='Y', multiple='stack')
plt.title('Coupon Acceptance by expiration')
# Out:
# /home/archana/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight
# Text(0.5, 1.0, 'Coupon Acceptance by expiration')

# %% [markdown]
# #### <font color='blue'> 1d expiration has slightly more influence on acceptance rate</font>

# %% [markdown]
# ## 10. What are the conclusions from the above analysis on whole dataset?

# %% [markdown]
# 1. Coupon type seem to affect the acceptance rate - Carry Out and Restaurant(<20>) show highest acceptance rate
# 2. Passenger type has some influence. Those traveling with Friends or Partner seem to more readily accept coupon
# 3. Expiration has a slight influence. Longer the expiration , more readily the coupon is accepted.
# 4. All other features have little to no influence on acceptance rate given the whole dataset.

# %% [markdown]
# ## <font color='green'>**Investigating the Bar Coupons**</font>
#
# Now, we will lead you through an exploration of just the bar related coupons.

# %% [markdown]
# ## 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
df_bar = data.query('coupon == "Bar"')

# %%
data_numeric_only = df_bar.select_dtypes(include=['int64'])
data_numeric_only = data_numeric_only.drop('toCoupon_GEQ5min', axis=1)
data_num_corr = data_numeric_only.corr()
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(data_num_corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# #### <font color='blue'>The above heat map shows that 'Bar' is the only feature that affects outcome Y given that the coupon offered is 'Bar'. That is higher the fequency of Bar visits, the more the chance of accepting the Bar coupon</font>

# %% [markdown]
# ## 2. What proportion of bar coupons were accepted?

# %%
coupon_accept_ratio = df_bar.query('Y == 1').shape[0] / df_bar.shape[0]
coupon_accept_ratio
# Out:
# 0.4099502487562189

# %%
#Does expiration play a role in acceptance?
df_bar.groupby('expiration')[['Y']].mean()
# Out:
#                    Y
# expiration
# 1d          0.412106
# 2h          0.402626

# %% [markdown]
# #### <font color='blue'> No impact seen</font>

# %% [markdown]
# ## 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
data_less_3 = df_bar.query('Bar <= 3')
data_more_3 = df_bar.query('Bar > 3')
coupon_accept_less_3 = data_less_3.query('Y == 1').shape[0]/data_less_3.shape[0]
coupon_accept_more_3 = data_more_3.query('Y == 1').shape[0]/data_more_3.shape[0]
print("Acceptance rate - Bar <= 3 is ",coupon_accept_less_3)
print("Acceptance rate - Bar > 3 is ",coupon_accept_more_3)
# Out:
# Acceptance rate - Bar <= 3 is  0.36772046589018303
# Acceptance rate - Bar > 3 is  0.7777777777777778

# %% [markdown]
# ## 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
data_more_1_more_25 = df_bar.query('Bar > 1 and age > 25')
data_less_1_less_25 = df_bar.query('Bar <= 1 or age <= 25')
coupon_accept_more_1_25 = data_more_1_more_25.query('Y == 1').shape[0]/data_more_1_more_25.shape[0]
coupon_accept_less_1_25 = data_less_1_less_25.query('Y == 1').shape[0]/data_less_1_less_25.shape[0]
print("Acceptance rate - Bar > 1 and age > 25 is ",coupon_accept_more_1_25)
print("Acceptance rate - others is ",coupon_accept_less_1_25)
# Out:
# Acceptance rate - Bar > 1 and age > 25 is  0.7009345794392523
# Acceptance rate - others is  0.33122629582806573

# %% [markdown]
# ## 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
data_more_1_plus_other = df_bar.query('Bar > 1 and passenger != "Kids" and occupation != "FarmingFishing&Forestry"')
data_less_1_plus_other = df_bar.query('Bar <= 1 or passenger == "Kids" or occupation == "FarmingFishing&Forestry"')
coupon_accept_more_1_plus_other = data_more_1_plus_other.query('Y == 1').shape[0]/data_more_1_plus_other.shape[0]
data_less_1_plus_other = data_less_1_plus_other.query('Y == 1').shape[0]/data_less_1_plus_other.shape[0]
print("Acceptance rate - Bar > 1 and no kid and farming is",coupon_accept_more_1_plus_other)
print("Acceptance rate - others is ",coupon_accept_less_1_25)
# Out:
# Acceptance rate - Bar > 1 and no kid and farming is 0.7168458781362007
# Acceptance rate - others is  0.33122629582806573

# %% [markdown]
# ## 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
data_first_crit = df_bar.query('Bar > 1 and passenger != "Kids" and maritalStatus != "Widowed"')
data_second_crit = df_bar.query('Bar > 1 and age < 30')
data_third_crit = df_bar.query('RestaurantLessThan20 > 4 and income < 50000')
coupon_first_crit = data_first_crit.query('Y == 1').shape[0]/data_first_crit.shape[0]
coupon_second_crit = data_second_crit.query('Y == 1').shape[0]/data_second_crit.shape[0]
coupon_third_crit = data_third_crit.query('Y == 1').shape[0]/data_third_crit.shape[0]
print("Acceptance rate - first criteria is",coupon_first_crit)
print("Acceptance rate - second criteria is ",coupon_second_crit)
print("Acceptance rate - third criteria is",coupon_third_crit)
# Out:
# Acceptance rate - first criteria is 0.7168458781362007
# Acceptance rate - second criteria is  0.7241379310344828
# Acceptance rate - third criteria is 0.45348837209302323

# %% [markdown]
# ## 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %%
data_more_1 = df_bar.query('Bar > 1')
data_less_1 = df_bar.query('Bar <= 1')
coupon_first_crit = data_more_1.query('Y == 1').shape[0]/data_more_1.shape[0]
coupon_second_crit = data_less_1.query('Y == 1').shape[0]/data_less_1.shape[0]
print("Acceptance rate - first criteria is",coupon_first_crit)
print("Acceptance rate - second criteria is ",coupon_second_crit)
# Out:
# Acceptance rate - first criteria is 0.6920529801324503
# Acceptance rate - second criteria is  0.2887624466571835

# %% [markdown]
# #### <font color='blue'> The above shows that frequency of Bar visit alone can determine whether the coupon is accepted or not. Even if we add other criteria such as non-kid passenger or marital status, occupation or age, the acceptance rate remains around 0.7 for higher Bar frequency and around 0.3 for lower Bar frequency. This is in line with what we observed in the heat map</font>

# %%
data_third_crit = df_bar.query('income < 50000')
coupon_third_crit = data_third_crit.query('Y == 1').shape[0]/data_third_crit.shape[0]
print("Acceptance rate - third criteria is",coupon_third_crit)

data_fourth_crit = df_bar.query('income >= 50000')
coupon_fourth_crit = data_fourth_crit.query('Y == 1').shape[0]/data_fourth_crit.shape[0]
print("Acceptance rate - fourth criteria is",coupon_fourth_crit)
# Out:
# Acceptance rate - third criteria is 0.4161849710982659
# Acceptance rate - fourth criteria is 0.40329218106995884

# %%
data_third_crit = df_bar.query('RestaurantLessThan20 > 4')
coupon_third_crit = data_third_crit.query('Y == 1').shape[0]/data_third_crit.shape[0]
print("Acceptance rate - third criteria is",coupon_third_crit)

data_fourth_crit = df_bar.query('RestaurantLessThan20 <= 4')
coupon_fourth_crit = data_fourth_crit.query('Y == 1').shape[0]/data_fourth_crit.shape[0]
print("Acceptance rate - fourth criteria is",coupon_fourth_crit)
# Out:
# Acceptance rate - third criteria is 0.4340878828229028
# Acceptance rate - fourth criteria is 0.39555202541699763

# %% [markdown]
# #### <font color='blue'>From the above two code cells, it can be found that both income and cheap restaurant visit frequency are not great indicators of whether a Bar coupon will be accepted. They show the similar acceptance rates for all income range and frequency of cheap restaurant visits.</font>

# %% [markdown]
# ## Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %% [markdown]
# ## <font color='green'> Analysing CarryAway coupon group</font>

# %% [markdown]
# ## 1. Create DataFrame that contains just 'Carry Out' coupons

# %%
print(data['coupon'].value_counts())
df_carry = data.query('coupon == "Carry Out"')
# Out:
# coupon
# Coffee House         3989
# Restaurant(<20)      2779
# Carry Out            2344
# Bar                  2010
# Restaurant(20-50)    1488
# Name: count, dtype: int64

# %%
data_numeric_only = df_carry.select_dtypes(include=['int64'])
data_numeric_only = data_numeric_only.drop('toCoupon_GEQ5min', axis=1)
data_num_corr = data_numeric_only.corr()
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(data_num_corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# #### <font color='blue'> Unlike the Bar data, the heatmap for 'Carry Out' coupon group does not show a strong correlation between frequency of carry away to the acceptance rate of Carry Out coupon although the rate of acceptance of CarryAway coupon is high in the overall dataset. The hypothesis here is most of the drivers don't want to delay their trip and are looking for fast options of getting food.</font>

# %% [markdown]
# ## 2. What is the acceptance rate of coupon?

# %%
coupon_acceptance_rate_carry = df_carry.query('Y == 1').shape[0]/df_carry.shape[0]
coupon_acceptance_rate_carry
# Out:
# 0.7337883959044369

# %% [markdown]
# ## 3. Lets study the effect of the following features on acceptance rate among those who were offered Carry Out coupon:
#    - CarryAway and age
#    - CarryAway and passenger
#    - CarryAway and income

# %%
data_first_crit = df_carry.query('CarryAway >= 1 and age <= 25')
data_second_crit = df_carry.query('CarryAway >= 1 and age > 25')
coupon_acceptance_first_crit =  data_first_crit.query('Y == 1').shape[0]/data_first_crit.shape[0]
coupon_acceptance_second_crit =  data_second_crit.query('Y == 1').shape[0]/data_second_crit.shape[0]
print(coupon_acceptance_first_crit, coupon_acceptance_second_crit)
# Out:
# 0.7348353552859619 0.7332949308755761

# %%
data_first_crit = df_carry.query('CarryAway < 1 and age <= 25')
data_second_crit = df_carry.query('CarryAway < 1 and age > 25')
coupon_acceptance_first_crit =  data_first_crit.query('Y == 1').shape[0]/data_first_crit.shape[0]
coupon_acceptance_second_crit =  data_second_crit.query('Y == 1').shape[0]/data_second_crit.shape[0]
print(coupon_acceptance_first_crit, coupon_acceptance_second_crit)
# Out:
# 0.8888888888888888 0.6818181818181818

# %% [markdown]
# #### <font color='blue'> No difference in acceptance rate due to age among those who CarryAway > 1 but there is a good amount of difference among those who do CarryAway < 1</font>

# %%
data_first_crit = df_carry.query('CarryAway >= 1 and passenger != "Kids"')
data_second_crit = df_carry.query('CarryAway >= 1 and passenger == "Kids"')
coupon_acceptance_first_crit =  data_first_crit.query('Y == 1').shape[0]/data_first_crit.shape[0]
coupon_acceptance_second_crit =  data_second_crit.query('Y == 1').shape[0]/data_second_crit.shape[0]
print(coupon_acceptance_first_crit, coupon_acceptance_second_crit)
# Out:
# 0.7357967667436489 0.7027027027027027

# %%
data_first_crit = df_carry.query('CarryAway < 1 and passenger != "Kids"')
data_second_crit = df_carry.query('CarryAway < 1 and passenger == "Kids"')
coupon_acceptance_first_crit =  data_first_crit.query('Y == 1').shape[0]/data_first_crit.shape[0]
coupon_acceptance_second_crit =  data_second_crit.query('Y == 1').shape[0]/data_second_crit.shape[0]
print(coupon_acceptance_first_crit, coupon_acceptance_second_crit)
# Out:
# 0.75 0.6666666666666666

# %% [markdown]
# #### <font color='blue'> There is some effect due to passenger == Kids and the difference is seen to be more among those who do CarryAway < 1 </font>

# %%
data_first_crit = df_carry.query('CarryAway >= 1 and income >= 30000')
data_second_crit = df_carry.query('CarryAway >= 1 and income < 30000')
coupon_acceptance_first_crit =  data_first_crit.query('Y == 1').shape[0]/data_first_crit.shape[0]
coupon_acceptance_second_crit =  data_second_crit.query('Y == 1').shape[0]/data_second_crit.shape[0]
print(coupon_acceptance_first_crit, coupon_acceptance_second_crit)
# Out:
# 0.7291666666666666 0.7486033519553073

# %%
data_first_crit = df_carry.query('CarryAway < 1 and income >= 30000')
data_second_crit = df_carry.query('CarryAway < 1 and income < 30000')
coupon_acceptance_first_crit =  data_first_crit.query('Y == 1').shape[0]/data_first_crit.shape[0]
coupon_acceptance_second_crit =  data_second_crit.query('Y == 1').shape[0]/data_second_crit.shape[0]
print(coupon_acceptance_first_crit, coupon_acceptance_second_crit)
# Out:
# 0.6923076923076923 1.0

# %% [markdown]
# #### <font color='blue'> Again here we see that if CarryAway < 1  , income plays a role in acceptance rate</font>

# %% [markdown]
# #### <font color='blue'>From the above, if CarryAway >= 1 , other features have little to no effect on acceptance rate but if CarryAway < 1 , people who never do CarryAway , seem to sway with other features. Lower income, no kids, and younger than 25 seem to accept the coupon more readily.

# %% [markdown]
# ## <font color='green'> Analysing Restaurant20To50 coupon group</font>

# %%
df_restmore20 = data.query('coupon == "Restaurant(20-50)"')
data_numeric_only = df_restmore20.select_dtypes(include=['int64'])
data_numeric_only = data_numeric_only.drop('toCoupon_GEQ5min', axis=1)
data_num_corr = data_numeric_only.corr()
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(data_num_corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %%
data_crit_1 = df_restmore20.query('Restaurant20To50 > 1')
data_crit_2 = df_restmore20.query('Restaurant20To50 <= 1')
coupon_accept_crit_1 = data_crit_1.query('Y == 1').shape[0]/data_crit_1.shape[0]
coupon_accept_crit_2 = data_crit_2.query('Y == 1').shape[0]/data_crit_2.shape[0]
print(coupon_accept_crit_1, coupon_accept_crit_2 )
# Out:
# 0.5616438356164384 0.37871033776867963

# %% [markdown]
# #### <font color='blue'> There is a difference between those who have the habit of visitng expensive restaurants more that those who don't frequent much.</font>

# %% [markdown]
# #### Among those who more frequently visit the expensive restaurants, is there a difference based on other features

# %%
data_crit_1 = df_restmore20.query('Restaurant20To50 > 1 and age <= 25')
data_crit_2 = df_restmore20.query('Restaurant20To50 > 1 and age > 25')
coupon_accept_crit_1 = data_crit_1.query('Y == 1').shape[0]/data_crit_1.shape[0]
coupon_accept_crit_2 = data_crit_2.query('Y == 1').shape[0]/data_crit_2.shape[0]
print(coupon_accept_crit_1, coupon_accept_crit_2 )
# Out:
# 0.5545454545454546 0.5635910224438903

# %%
data_crit_1 = df_restmore20.query('Restaurant20To50 > 1 and income < 20000')
data_crit_2 = df_restmore20.query('Restaurant20To50 > 1 and income > 20000')
coupon_accept_crit_1 = data_crit_1.query('Y == 1').shape[0]/data_crit_1.shape[0]
coupon_accept_crit_2 = data_crit_2.query('Y == 1').shape[0]/data_crit_2.shape[0]
print(coupon_accept_crit_1, coupon_accept_crit_2 )
# Out:
# 0.5882352941176471 0.5563380281690141

# %%
data_crit_1 = df_restmore20.query('Restaurant20To50 > 1 and passenger != "Kids"')
data_crit_2 = df_restmore20.query('Restaurant20To50 > 1 and passenger == "Kids"')
coupon_accept_crit_1 = data_crit_1.query('Y == 1').shape[0]/data_crit_1.shape[0]
coupon_accept_crit_2 = data_crit_2.query('Y == 1').shape[0]/data_crit_2.shape[0]
print(coupon_accept_crit_1, coupon_accept_crit_2 )
# Out:
# 0.5825892857142857 0.4126984126984127

# %% [markdown]
# #### <font color='blue'> Age, income do not play a role in acceptance rate if the frequency of visit is higher. But if the passenger is a Kid, there is a slightly lower chance of accepting the coupon which aligns with overall lower acceptance rate with Kids.</font>

# %% [markdown]
# #### Among those who don't frequent the expensive restaurants, how is the acceptance rate affected by other factors?

# %%
data_crit_1 = df_restmore20.query('Restaurant20To50 <= 1 and passenger != "Kids"')
data_crit_2 = df_restmore20.query('Restaurant20To50 <= 1 and passenger == "Kids"')
coupon_accept_crit_1 = data_crit_1.query('Y == 1').shape[0]/data_crit_1.shape[0]
coupon_accept_crit_2 = data_crit_2.query('Y == 1').shape[0]/data_crit_2.shape[0]
print(coupon_accept_crit_1, coupon_accept_crit_2 )
# Out:
# 0.3829296424452134 0.34545454545454546

# %%
data_crit_1 = df_restmore20.query('Restaurant20To50 <= 1 and income < 20000')
data_crit_2 = df_restmore20.query('Restaurant20To50 <= 1 and income > 20000')
coupon_accept_crit_1 = data_crit_1.query('Y == 1').shape[0]/data_crit_1.shape[0]
coupon_accept_crit_2 = data_crit_2.query('Y == 1').shape[0]/data_crit_2.shape[0]
print(coupon_accept_crit_1, coupon_accept_crit_2 )
# Out:
# 0.2979591836734694 0.4057377049180328

# %%
data_crit_1 = df_restmore20.query('Restaurant20To50 <= 1 and age <= 25')
data_crit_2 = df_restmore20.query('Restaurant20To50 <= 1 and age > 25')
coupon_accept_crit_1 = data_crit_1.query('Y == 1').shape[0]/data_crit_1.shape[0]
coupon_accept_crit_2 = data_crit_2.query('Y == 1').shape[0]/data_crit_2.shape[0]
print(coupon_accept_crit_1, coupon_accept_crit_2 )
# Out:
# 0.38247011952191234 0.3774104683195592

# %% [markdown]
# #### <font color='blue'> No  effect of age or passenger on drivers who don't frequent expensive restaurants. Income, on the other hand, shows higher acceptance rate among those who have an income greater than 20000</font>

# %% [markdown]
# ### Finding which coupon groups impact acceptance rate by themselves to some degree

# %%
data['coupon'].value_counts()
df_restless20 = data.query('coupon == "Restaurant(<20)"')
df_restmore20 = data.query('coupon == "Restaurant(20-50)"')
df_coffee = data.query('coupon == "Coffee House"')

# %%
data_numeric_only = df_restless20.select_dtypes(include=['int64'])
data_numeric_only = data_numeric_only.drop('toCoupon_GEQ5min', axis=1)
corr_to_Y = data_numeric_only.corr().iloc[13,7]
corr_to_Y
# Out:
# 0.06172834062421381

# %%
data_numeric_only = df_restmore20.select_dtypes(include=['int64'])
data_numeric_only = data_numeric_only.drop('toCoupon_GEQ5min', axis=1)
corr_to_Y = data_numeric_only.corr().iloc[13,8]
corr_to_Y
# Out:
# 0.18837178187844925

# %%
data_numeric_only = df_coffee.select_dtypes(include=['int64'])
data_numeric_only = data_numeric_only.drop('toCoupon_GEQ5min', axis=1)
corr_to_Y = data_numeric_only.corr().iloc[13,5]
corr_to_Y
# Out:
# 0.2908610888803082

# %% [markdown]
# #### <font color='blue'> Coffee House has a more positve correlation to acceptance compared to others. Compared to the overall heatmap correlation for Restaurant 20-50, this subset of drivers who were offered Restaurant 20-50 coupon shows higher correlation to acceptance. Restautant < 20 shows very weak correlation just like CarryAway. </font>

# %% [markdown]
# ### Are drivers with lower income, no kids, younger than 25 have higher acceptance rate than others?

# %%
data_crit = data.query('income < 30000 and age < 25 and passenger != "Kids"')
data_rest = data.query('income > 30000 or age >= 25 or passenger == "Kids"')
coupon_accept_crit = data_crit.query('Y == 1').shape[0]/data_crit.shape[0]
coupon_accept_rest = data_rest.query('Y == 1').shape[0]/data_rest.shape[0]
print(coupon_accept_crit, coupon_accept_rest )
# Out:
# 0.6 0.5646346735840899

# %% [markdown]
# #### <font color='blue'> No big difference seen here</font>

# %% [markdown]
# ### Gathering all the data above, lets see what factors result in high accpetance of Bar or CarryAway coupons.
# 1. Bar coupon - frequency of Bar visits alone is a great indicator. If the frequency is low, the acceptance rate drops down. So do not offer Bar coupon to drivers who dont visit Bar more than once a month.
# 2. Carry Out coupon - frequenct of CarryAway does not determine the accpetance of Carry Out coupon. Overall, this coupon can be offered to any driver with high acceptance rate. If CarryAway > 1 , this coupon can surely be offered. If CarryAway < 1, take into consideration income, age, passenger to start with. Lower income, younger, no kid drivers tend to accept it more readily.
# 3. Coffee House coupons can be offered to those who frequent coffee houses more. This is based on general positive correlation between Coffee House visits and Y acceptance.
# 4. Similar to CarryAway, RestaurantLessThan20 can be offered to any driver with high acceptance.
# 5. Restaurant 20-50 can be offered to those who are in the habit of frequently viting these restaurants.

# %% [markdown]
# ### Analyzing Restaurant20To50 Coupons
